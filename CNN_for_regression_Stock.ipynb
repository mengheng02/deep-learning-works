# %% [markdown]
# <a href="https://colab.research.google.com/github/mengheng02/deep-learning-works/blob/main/CNN_for_regression_Stock.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive # Mount the google drive for data loading
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Import some related dependencies
# 1.   Numpy: a package for array transformation
# 2.   Pandas: a package for loading data with .csv/.xlsx formats
# 3.   Matplotlib: a package for data visualization
# 4.   Skearn: a package including many machine learning approaches
# 5.   Tensorflow: a package for neural networks modeling
# 5.   Keras: a package for neural networks modeling which is established on Tensorflow

# %%
import numpy as np #helps for array operation
import pandas as pd #helps to read the data
import matplotlib.pyplot as plt #helps with graphical plots
from sklearn.preprocessing import MinMaxScaler #helps for normalization of input data
import keras            #helps for CNN model construction
import tensorflow as tf #helps for CNN model construction

# %% [markdown]
# # Load data using Pandas package
#
# 1.   Data visualization
# 2.   Data segmentation
# 3.   Training data and testing data split

# %%
data = pd.read_csv('/content/drive/MyDrive/lab_data/Stock.csv')  #Load data with the corresponding path in google drive

# %%
data.head()
# Out:
#          date  item_cnt_day
# 0  2013-01-01        1951.0
# 1  2013-01-02        3817.0
# 2  2013-01-03        3846.0
# 3  2013-01-04        2574.0
# 4  2013-01-05        4863.0

# %%
# Visualization
plt.figure(figsize=(8,6))
plt.plot(data['date'], data['item_cnt_day'])
plt.xticks(['2013-01-01','2014-01-01','2015-01-01','2015-12-10'])
plt.xlabel('Date', fontsize=20)
plt.ylabel('Stock price (GBP)', fontsize=20)
plt.show()

# %%
scaler = MinMaxScaler(feature_range=(-1,1))                                     # Normalization step, the output will be scaled to [-1,1]
scaled_price = scaler.fit_transform(data['item_cnt_day'].values.reshape(-1,1))  # Data Normalization

# %%
# Visualization of scaled data
plt.figure(figsize=(8,6))
plt.plot(data['date'], scaled_price)
plt.xticks(['2013-01-01','2014-01-01','2015-01-01','2015-12-10'])
plt.xlabel('Date', fontsize=20)
plt.ylabel('Stock price (GBP)', fontsize=20)
plt.show()

# %%
# Segment data using sliding windows
X, Y = [], []
timestep = 30                                       # Sliding window size
k = 850                                             # The threshold for the training set and the testing set
for i in range(len(scaled_price)- timestep):        # Data Segmentation.
  X.append(scaled_price[i:i+timestep])
  Y.append(scaled_price[i+timestep])
X=np.asarray(X)
Y=np.asarray(Y)

# Training data and testing data split
X_train = X[:k,:,:]                                 # Training data
y_train = Y[:k]                                     # Training labels

X_test = X[k:,:,:]                                  # Testing data
y_test = Y[k:]                                      # Testing labels

print (X_train.shape)
print (X_test.shape)
# Out:
# (850, 30, 1)
# (194, 30, 1)

# %%
X_train = np.expand_dims(X_train, axis=2) # Add a dimension for each training sample - 1 x 30 x 1 x 1
X_test = np.expand_dims(X_test, axis=2)   # Add a dimension for each testing sample - 1 x 30 x 1 x 1
print (X_train.shape)
print (X_test.shape)
# Out:
# (850, 30, 1, 1)
# (194, 30, 1, 1)

# %% [markdown]
# # Model training

# %%
# LeNet-5 model for model training
model = keras.Sequential()
model.add(keras.layers.Conv2D(filters=6, kernel_size=(5,1), strides=(1,1), padding='same', activation='relu', input_shape=(30, 1, 1)))  # The first convolutional layer. Input shape is 8x1x1 and activation function is Rectified Linear Unit (ReLU).\
                                                           # Kernel size and stride are set as (5,1) and (1,1), respectively. The number of convolutional kernels is 6. Besides, the zero padding is 'same', thus the output shape is (30/1) x 1 x 6 = 30x1x6, which is the same as the input shape.
model.add(keras.layers.MaxPool2D(pool_size=(2,1), strides=(2,1)))  # The first maxpooling layer. The pool size and stride are both (2,1), thus the output shape is 15x1x6, where 15 = (30-2)/2 + 1.
model.add(keras.layers.Conv2D(filters=16, kernel_size=(5,1), strides=(1,1), activation='relu')) # The second convolutional layer. The output shape is 11x1x16, where 11 = (15-5)/1 + 1.
model.add(keras.layers.MaxPool2D(pool_size=(2,1), strides=(2,1)))  # The second maxpooling layer. The pool size and stride are both (2,1). The output shape is 5x1x16, where 5 = ⌊(11-2)/2⌋+1.
model.add(keras.layers.Flatten())                          # The previous output is flattened to be a vector.
model.add(keras.layers.Dense(120, activation='relu'))      # The first fully connected layer.
model.add(keras.layers.Dropout(0.2))                       # Dropout layer
model.add(keras.layers.Dense(84, activation='relu'))       # The second fully connected layer.
model.add(keras.layers.Dropout(0.2))                       # Dropout layer
model.add(keras.layers.Dense(1))                           # we have 1 neuron for output (Price).
model.summary()                                            # Summary the constructed model.
model.compile(tf.keras.optimizers.Adam(learning_rate = 1e-3), 'mean_squared_error') # Model construction with a SGD optimizer and a mean squared error loss function.
model.fit(X_train, y_train, epochs = 100, batch_size = 32, verbose = 2, validation_data = (X_test, y_test))    # Model training with some hyperparameters.
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 1, 6)          36
#
#  max_pooling2d (MaxPooling2  (None, 15, 1, 6)          0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 11, 1, 16)         496
#
#  max_pooling2d_1 (MaxPoolin  (None, 5, 1, 16)          0
#  g2D)
#
#  flatten (Flatten)           (None, 80)                0
#
#  dense (Dense)               (None, 120)               9720
#
#  dropout (Dropout)           (None, 120)               0
#
#  dense_1 (Dense)             (None, 84)                10164
#
#  dropout_1 (Dropout)         (None, 84)                0
#
#  dense_2 (Dense)             (None, 1)                 85
#
# =================================================================
# Total params: 20501 (80.08 KB)
# Trainable params: 20501 (80.08 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 27/27 - 9s - loss: 0.0995 - val_loss: 0.0718 - 9s/epoch - 320ms/step
# Epoch 2/100
# 27/27 - 0s - loss: 0.0592 - val_loss: 0.0664 - 136ms/epoch - 5ms/step
# Epoch 3/100
# 27/27 - 0s - loss: 0.0582 - val_loss: 0.0588 - 133ms/epoch - 5ms/step
# Epoch 4/100
# 27/27 - 0s - loss: 0.0560 - val_loss: 0.0524 - 141ms/epoch - 5ms/step
# Epoch 5/100
# 27/27 - 0s - loss: 0.0514 - val_loss: 0.0379 - 127ms/epoch - 5ms/step
# Epoch 6/100
# 27/27 - 0s - loss: 0.0520 - val_loss: 0.0339 - 133ms/epoch - 5ms/step
# Epoch 7/100
# 27/27 - 0s - loss: 0.0478 - val_loss: 0.0284 - 122ms/epoch - 5ms/step
# Epoch 8/100
# 27/27 - 0s - loss: 0.0472 - val_loss: 0.0231 - 126ms/epoch - 5ms/step
# Epoch 9/100
# 27/27 - 0s - loss: 0.0467 - val_loss: 0.0242 - 129ms/epoch - 5ms/step
# Epoch 10/100
# 27/27 - 0s - loss: 0.0458 - val_loss: 0.0225 - 150ms/epoch - 6ms/step
# Epoch 11/100
# 27/27 - 0s - loss: 0.0441 - val_loss: 0.0230 - 125ms/epoch - 5ms/step
# Epoch 12/100
# 27/27 - 0s - loss: 0.0437 - val_loss: 0.0245 - 127ms/epoch - 5ms/step
# Epoch 13/100
# 27/27 - 0s - loss: 0.0402 - val_loss: 0.0225 - 123ms/epoch - 5ms/step
# Epoch 14/100
# 27/27 - 0s - loss: 0.0414 - val_loss: 0.0281 - 129ms/epoch - 5ms/step
# Epoch 15/100
# 27/27 - 0s - loss: 0.0392 - val_loss: 0.0252 - 127ms/epoch - 5ms/step
# Epoch 16/100
# 27/27 - 0s - loss: 0.0386 - val_loss: 0.0260 - 129ms/epoch - 5ms/step
# Epoch 17/100
# 27/27 - 0s - loss: 0.0368 - val_loss: 0.0221 - 132ms/epoch - 5ms/step
# Epoch 18/100
# 27/27 - 0s - loss: 0.0352 - val_loss: 0.0234 - 141ms/epoch - 5ms/step
# Epoch 19/100
# 27/27 - 0s - loss: 0.0352 - val_loss: 0.0417 - 126ms/epoch - 5ms/step
# Epoch 20/100
# 27/27 - 0s - loss: 0.0342 - val_loss: 0.0230 - 141ms/epoch - 5ms/step
# Epoch 21/100
# 27/27 - 0s - loss: 0.0346 - val_loss: 0.0323 - 124ms/epoch - 5ms/step
# Epoch 22/100
# 27/27 - 0s - loss: 0.0321 - val_loss: 0.0235 - 132ms/epoch - 5ms/step
# Epoch 23/100
# 27/27 - 0s - loss: 0.0321 - val_loss: 0.0256 - 133ms/epoch - 5ms/step
# Epoch 24/100
# 27/27 - 0s - loss: 0.0317 - val_loss: 0.0311 - 131ms/epoch - 5ms/step
# Epoch 25/100
# 27/27 - 0s - loss: 0.0299 - val_loss: 0.0235 - 137ms/epoch - 5ms/step
# Epoch 26/100
# 27/27 - 0s - loss: 0.0317 - val_loss: 0.0352 - 124ms/epoch - 5ms/step
# Epoch 27/100
# 27/27 - 0s - loss: 0.0309 - val_loss: 0.0320 - 135ms/epoch - 5ms/step
# Epoch 28/100
# 27/27 - 0s - loss: 0.0287 - val_loss: 0.0289 - 125ms/epoch - 5ms/step
# Epoch 29/100
# 27/27 - 0s - loss: 0.0279 - val_loss: 0.0334 - 137ms/epoch - 5ms/step
# Epoch 30/100
# 27/27 - 0s - loss: 0.0275 - val_loss: 0.0269 - 142ms/epoch - 5ms/step
# Epoch 31/100
# 27/27 - 0s - loss: 0.0275 - val_loss: 0.0234 - 149ms/epoch - 6ms/step
# Epoch 32/100
# 27/27 - 0s - loss: 0.0266 - val_loss: 0.0245 - 127ms/epoch - 5ms/step
# Epoch 33/100
# 27/27 - 0s - loss: 0.0273 - val_loss: 0.0267 - 141ms/epoch - 5ms/step
# Epoch 34/100
# 27/27 - 0s - loss: 0.0254 - val_loss: 0.0327 - 130ms/epoch - 5ms/step
# Epoch 35/100
# 27/27 - 0s - loss: 0.0266 - val_loss: 0.0225 - 122ms/epoch - 5ms/step
# Epoch 36/100
# 27/27 - 0s - loss: 0.0279 - val_loss: 0.0289 - 134ms/epoch - 5ms/step
# Epoch 37/100
# 27/27 - 0s - loss: 0.0258 - val_loss: 0.0265 - 129ms/epoch - 5ms/step
# Epoch 38/100
# 27/27 - 0s - loss: 0.0248 - val_loss: 0.0271 - 127ms/epoch - 5ms/step
# Epoch 39/100
# 27/27 - 0s - loss: 0.0261 - val_loss: 0.0230 - 131ms/epoch - 5ms/step
# Epoch 40/100
# 27/27 - 0s - loss: 0.0256 - val_loss: 0.0267 - 133ms/epoch - 5ms/step
# Epoch 41/100
# 27/27 - 0s - loss: 0.0241 - val_loss: 0.0243 - 135ms/epoch - 5ms/step
# Epoch 42/100
# 27/27 - 0s - loss: 0.0248 - val_loss: 0.0227 - 126ms/epoch - 5ms/step
# Epoch 43/100
# 27/27 - 0s - loss: 0.0231 - val_loss: 0.0247 - 143ms/epoch - 5ms/step
# Epoch 44/100
# 27/27 - 0s - loss: 0.0242 - val_loss: 0.0275 - 198ms/epoch - 7ms/step
# Epoch 45/100
# 27/27 - 0s - loss: 0.0227 - val_loss: 0.0293 - 172ms/epoch - 6ms/step
# Epoch 46/100
# 27/27 - 0s - loss: 0.0225 - val_loss: 0.0302 - 237ms/epoch - 9ms/step
# Epoch 47/100
# 27/27 - 0s - loss: 0.0240 - val_loss: 0.0275 - 242ms/epoch - 9ms/step
# Epoch 48/100
# 27/27 - 0s - loss: 0.0226 - val_loss: 0.0334 - 256ms/epoch - 9ms/step
# Epoch 49/100
# 27/27 - 0s - loss: 0.0209 - val_loss: 0.0243 - 192ms/epoch - 7ms/step
# Epoch 50/100
# 27/27 - 0s - loss: 0.0221 - val_loss: 0.0322 - 173ms/epoch - 6ms/step
# Epoch 51/100
# 27/27 - 0s - loss: 0.0212 - val_loss: 0.0254 - 228ms/epoch - 8ms/step
# Epoch 52/100
# 27/27 - 0s - loss: 0.0204 - val_loss: 0.0300 - 183ms/epoch - 7ms/step
# Epoch 53/100
# 27/27 - 0s - loss: 0.0196 - val_loss: 0.0240 - 169ms/epoch - 6ms/step
# Epoch 54/100
# 27/27 - 0s - loss: 0.0194 - val_loss: 0.0277 - 222ms/epoch - 8ms/step
# Epoch 55/100
# 27/27 - 0s - loss: 0.0211 - val_loss: 0.0322 - 187ms/epoch - 7ms/step
# Epoch 56/100
# 27/27 - 0s - loss: 0.0202 - val_loss: 0.0249 - 248ms/epoch - 9ms/step
# Epoch 57/100
# 27/27 - 0s - loss: 0.0203 - val_loss: 0.0279 - 179ms/epoch - 7ms/step
# Epoch 58/100
# 27/27 - 0s - loss: 0.0184 - val_loss: 0.0263 - 229ms/epoch - 8ms/step
# Epoch 59/100
# 27/27 - 0s - loss: 0.0197 - val_loss: 0.0294 - 186ms/epoch - 7ms/step
# Epoch 60/100
# 27/27 - 0s - loss: 0.0189 - val_loss: 0.0249 - 127ms/epoch - 5ms/step
# Epoch 61/100
# 27/27 - 0s - loss: 0.0181 - val_loss: 0.0271 - 135ms/epoch - 5ms/step
# Epoch 62/100
# 27/27 - 0s - loss: 0.0191 - val_loss: 0.0252 - 135ms/epoch - 5ms/step
# Epoch 63/100
# 27/27 - 0s - loss: 0.0183 - val_loss: 0.0304 - 134ms/epoch - 5ms/step
# Epoch 64/100
# 27/27 - 0s - loss: 0.0168 - val_loss: 0.0305 - 125ms/epoch - 5ms/step
# Epoch 65/100
# 27/27 - 0s - loss: 0.0183 - val_loss: 0.0267 - 128ms/epoch - 5ms/step
# Epoch 66/100
# 27/27 - 0s - loss: 0.0167 - val_loss: 0.0258 - 124ms/epoch - 5ms/step
# Epoch 67/100
# 27/27 - 0s - loss: 0.0163 - val_loss: 0.0254 - 130ms/epoch - 5ms/step
# Epoch 68/100
# 27/27 - 0s - loss: 0.0168 - val_loss: 0.0257 - 132ms/epoch - 5ms/step
# Epoch 69/100
# 27/27 - 0s - loss: 0.0162 - val_loss: 0.0293 - 135ms/epoch - 5ms/step
# Epoch 70/100
# 27/27 - 0s - loss: 0.0162 - val_loss: 0.0245 - 131ms/epoch - 5ms/step
# Epoch 71/100
# 27/27 - 0s - loss: 0.0155 - val_loss: 0.0284 - 119ms/epoch - 4ms/step
# Epoch 72/100
# 27/27 - 0s - loss: 0.0156 - val_loss: 0.0318 - 127ms/epoch - 5ms/step
# Epoch 73/100
# 27/27 - 0s - loss: 0.0151 - val_loss: 0.0258 - 134ms/epoch - 5ms/step
# Epoch 74/100
# 27/27 - 0s - loss: 0.0135 - val_loss: 0.0303 - 138ms/epoch - 5ms/step
# Epoch 75/100
# 27/27 - 0s - loss: 0.0173 - val_loss: 0.0395 - 115ms/epoch - 4ms/step
# Epoch 76/100
# 27/27 - 0s - loss: 0.0152 - val_loss: 0.0285 - 126ms/epoch - 5ms/step
# Epoch 77/100
# 27/27 - 0s - loss: 0.0146 - val_loss: 0.0269 - 137ms/epoch - 5ms/step
# Epoch 78/100
# 27/27 - 0s - loss: 0.0151 - val_loss: 0.0234 - 131ms/epoch - 5ms/step
# Epoch 79/100
# 27/27 - 0s - loss: 0.0141 - val_loss: 0.0291 - 125ms/epoch - 5ms/step
# Epoch 80/100
# 27/27 - 0s - loss: 0.0140 - val_loss: 0.0300 - 122ms/epoch - 5ms/step
# Epoch 81/100
# 27/27 - 0s - loss: 0.0138 - val_loss: 0.0293 - 161ms/epoch - 6ms/step
# Epoch 82/100
# 27/27 - 0s - loss: 0.0136 - val_loss: 0.0279 - 138ms/epoch - 5ms/step
# Epoch 83/100
# 27/27 - 0s - loss: 0.0131 - val_loss: 0.0279 - 140ms/epoch - 5ms/step
# Epoch 84/100
# 27/27 - 0s - loss: 0.0133 - val_loss: 0.0298 - 144ms/epoch - 5ms/step
# Epoch 85/100
# 27/27 - 0s - loss: 0.0126 - val_loss: 0.0287 - 147ms/epoch - 5ms/step
# Epoch 86/100
# 27/27 - 0s - loss: 0.0117 - val_loss: 0.0315 - 137ms/epoch - 5ms/step
# Epoch 87/100
# 27/27 - 0s - loss: 0.0126 - val_loss: 0.0346 - 148ms/epoch - 5ms/step
# Epoch 88/100
# 27/27 - 0s - loss: 0.0123 - val_loss: 0.0329 - 142ms/epoch - 5ms/step
# Epoch 89/100
# 27/27 - 0s - loss: 0.0126 - val_loss: 0.0257 - 128ms/epoch - 5ms/step
# Epoch 90/100
# 27/27 - 0s - loss: 0.0109 - val_loss: 0.0296 - 121ms/epoch - 4ms/step
# Epoch 91/100
# 27/27 - 0s - loss: 0.0115 - val_loss: 0.0285 - 123ms/epoch - 5ms/step
# Epoch 92/100
# 27/27 - 0s - loss: 0.0105 - val_loss: 0.0274 - 148ms/epoch - 5ms/step
# Epoch 93/100
# 27/27 - 0s - loss: 0.0111 - val_loss: 0.0330 - 134ms/epoch - 5ms/step
# Epoch 94/100
# 27/27 - 0s - loss: 0.0107 - val_loss: 0.0314 - 124ms/epoch - 5ms/step
# Epoch 95/100
# 27/27 - 0s - loss: 0.0115 - val_loss: 0.0356 - 125ms/epoch - 5ms/step
# Epoch 96/100
# 27/27 - 0s - loss: 0.0107 - val_loss: 0.0285 - 129ms/epoch - 5ms/step
# Epoch 97/100
# 27/27 - 0s - loss: 0.0099 - val_loss: 0.0345 - 140ms/epoch - 5ms/step
# Epoch 98/100
# 27/27 - 0s - loss: 0.0107 - val_loss: 0.0292 - 122ms/epoch - 5ms/step
# Epoch 99/100
# 27/27 - 0s - loss: 0.0106 - val_loss: 0.0333 - 137ms/epoch - 5ms/step
# Epoch 100/100
# 27/27 - 0s - loss: 0.0103 - val_loss: 0.0310 - 135ms/epoch - 5ms/step

# %% [markdown]
# # Model testing

# %%
scaled_preds = model.predict(X_test)                    # Prediction of testing set.
preds = scaler.inverse_transform(scaled_preds)          # Inverse the prediction values, because the predicted values are in [-1,1].
ytest = scaler.inverse_transform(y_test.reshape(-1,1))  # Inverse the actual values.
# Out:
# 7/7 [==============================] - 0s 3ms/step

# %%
# Visualization of predicted stocks and actual stocks
plt.figure(figsize=(20,10))
plt.plot(data['date'].iloc[k+timestep:], ytest, c = 'g', label = 'Actual stock price')
plt.plot(data['date'].iloc[k+timestep:], preds, c = 'r', label = 'Predicted stock price')
plt.xticks(['2015-06-01','2015-07-01','2015-08-01','2015-09-01','2015-10-01','2015-11-01','2015-12-10'], fontsize = 20)
plt.xlabel('Date', fontsize=20)
plt.ylabel('Stock price (GBP)', fontsize=20)
plt.legend(fontsize=20)
plt.show()
